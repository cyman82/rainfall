# %%
import pandas as pd

DATA_PATH = "../ingestion/data/processed/district_flood_ml_dataset.csv"
df = pd.read_csv(DATA_PATH)

df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year

# Flood counts per year
yearly_floods = df.groupby("year")["flood_risk"].sum().sort_index()
yearly_floods
# Out:
# year
# 2015     40
# 2016      0
# 2017    121
# 2018      3
# 2019      2
# 2020      0
# 2021     18
# 2022      1
# 2023      0
# 2024      0
# Name: flood_risk, dtype: int64
