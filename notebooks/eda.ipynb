# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

DATA_PATH = "../ingestion/data/processed/district_weather_soil_daily.csv"
df = pd.read_csv(DATA_PATH)

df["date"] = pd.to_datetime(df["date"])
df.head()
# Out:
#         date      district  rainfall_mm  temperature_2m_mean  \
# 0 2015-01-01  Chengalpattu          0.0                 24.9
# 1 2015-01-02  Chengalpattu          1.3                 25.2
# 2 2015-01-03  Chengalpattu          1.2                 25.2
# 3 2015-01-04  Chengalpattu          0.4                 25.1
# 4 2015-01-05  Chengalpattu          0.2                 24.8
#
#    relative_humidity_2m_mean  surface_pressure_mean  wind_speed_10m_mean  \
# 0                         87                 1003.3                  5.6
# 1                         88                 1005.7                  8.0
# 2                         89                 1006.9                  6.4
# 3                         88                 1006.9                  5.3
# 4                         83                 1006.6                  7.9
#
#    cloud_cover_mean  soil_moisture soil_moisture_source soil_source
# 0                38        0.29004            simulated   simulated
# ...

# %%
df.shape
# Out:
# (21918, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21918 entries, 0 to 21917
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       21918 non-null  datetime64[ns]
#  1   district                   21918 non-null  object
#  2   rainfall_mm                21918 non-null  float64
#  3   temperature_2m_mean        21918 non-null  float64
#  4   relative_humidity_2m_mean  21918 non-null  int64
#  5   surface_pressure_mean      21918 non-null  float64
#  6   wind_speed_10m_mean        21918 non-null  float64
#  7   cloud_cover_mean           21918 non-null  int64
#  8   soil_moisture              8766 non-null   float64
#  9   soil_moisture_source       8766 non-null   object
#  10  soil_source                8766 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 1.8+ MB

# %%
df.isna().sum()
# Out:
# date                         0
# district                     0
# rainfall_mm                  0
# temperature_2m_mean          0
# relative_humidity_2m_mean    0
# surface_pressure_mean        0
# wind_speed_10m_mean          0
# cloud_cover_mean             0
# soil_moisture                0
# soil_moisture_source         0
# soil_source                  0
# dtype: int64

# %%
df[df["soil_moisture"].isna()][["district", "date"]].head(10)
# Out:
#           district       date
# 1461  Chengalpattu 2019-01-01
# 1462  Chengalpattu 2019-01-02
# 1463  Chengalpattu 2019-01-03
# 1464  Chengalpattu 2019-01-04
# 1465  Chengalpattu 2019-01-05
# 1466  Chengalpattu 2019-01-06
# 1467  Chengalpattu 2019-01-07
# 1468  Chengalpattu 2019-01-08
# 1469  Chengalpattu 2019-01-09
# 1470  Chengalpattu 2019-01-10

# %%
df[df["soil_moisture"].isna()]["date"].min(), df[df["soil_moisture"].isna()]["date"].max()
# Out:
# (Timestamp('2019-01-01 00:00:00'), Timestamp('2024-12-31 00:00:00'))

# %%
df.isna().sum()
# Out:
# date                             0
# district                         0
# rainfall_mm                      0
# temperature_2m_mean              0
# relative_humidity_2m_mean        0
# surface_pressure_mean            0
# wind_speed_10m_mean              0
# cloud_cover_mean                 0
# soil_moisture                13152
# soil_moisture_source         13152
# soil_source                  13152
# dtype: int64

# %%
import pandas as pd

soil = pd.read_csv(
    "../ingestion/data/processed/district_soil_simulated.csv"
)

soil["date"] = pd.to_datetime(soil["date"])

soil["date"].min(), soil["date"].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2024-12-31 00:00:00'))

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\91924\OneDrive\Documents\rainfall\notebooks

# %%
import os

path = "../ingestion/data/processed/district_soil_simulated.csv"
print(os.path.abspath(path))
# Out:
# C:\Users\91924\OneDrive\Documents\rainfall\ingestion\data\processed\district_soil_simulated.csv

# %%
import os
import pandas as pd

PROJECT_ROOT = os.path.abspath("..")

SOIL_PATH = os.path.join(
    PROJECT_ROOT,
    "ingestion",
    "data",
    "processed",
    "district_soil_simulated.csv"
)

soil = pd.read_csv(SOIL_PATH)
soil["date"] = pd.to_datetime(soil["date"])

soil["date"].min(), soil["date"].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2018-12-31 00:00:00'))
